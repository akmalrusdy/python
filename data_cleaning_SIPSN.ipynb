# %% [markdown]
# <a href="https://colab.research.google.com/github/akmalrusdy/python/blob/main/data_cleaning_SIPSN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df1=df.dropna()
df1=df.dropna(axis=0)

# %%
df1.head()
# Out:
#    Tahun Provinsi    Kabupaten/Kota  Sisa Makanan (%)  Kayu-Ranting (%)  \
# 2   2019     Aceh   Kab. Aceh Timur              37.0              14.0
# 3   2019     Aceh  Kab. Aceh Tengah              20.0              20.0
# 4   2019     Aceh  Kab. Aceh Tengah              22.0              18.0
# 5   2019     Aceh   Kab. Aceh Barat              20.0              10.0
# 6   2019     Aceh        Kab. Pidie               4.0               2.5
#
#    Kertas-Karton (%)  Plastik(%)  Logam(%)  Kain(%)  Karet- Kulit (%)  ...  \
# 2                5.0        26.0       5.0      3.0               2.0  ...
# 3               10.0        25.0       5.0     10.0               5.0  ...
# 4                7.0        26.0       3.0     11.0               5.0  ...
# 5               15.0        20.0       2.0      3.0               2.0  ...
# 6                4.3        23.7       1.0      1.0               1.0  ...
#
#    Lainnya(%)  total1  Rumah Tangga(ton)  Perkantoran(ton)  Pasar(ton)  \
# ...

# %%
df2 = df1.drop(df1[df1.total1 < 100].index)

# %%
df2
# Out:
#      Tahun        Provinsi         Kabupaten/Kota  Sisa Makanan (%)  \
# 2     2019            Aceh        Kab. Aceh Timur             37.00
# 3     2019            Aceh       Kab. Aceh Tengah             20.00
# 4     2019            Aceh       Kab. Aceh Tengah             22.00
# 5     2019            Aceh        Kab. Aceh Barat             20.00
# 7     2019            Aceh          Kab. Simeulue              5.75
# ..     ...             ...                    ...               ...
# 714   2021  Sumatera Utara           Kab. Samosir             25.00
# 720   2021  Sumatera Utara  Kota Pematang Siantar             45.00
# 722   2021  Sumatera Utara           Kota Sibolga             28.34
# 724   2020  Sumatera Utara     Kota Tebing Tinggi             62.70
# 725   2021  Sumatera Utara     Kota Tebing Tinggi             62.70
#
#      Kayu-Ranting (%)  Kertas-Karton (%)  Plastik(%)  Logam(%)  Kain(%)  \
# 2               14.00               5.00       26.00      5.00     3.00
# ...

# %%
from google.colab import files

df2.to_csv('Data SIPSN.csv', encoding = 'utf-8-sig') 
files.download('Data SIPSN.csv')

# %% [markdown]
# -

# %% [markdown]
# -

# %%
# !google-drive-ocamlfuse -cc
# Out:
# /bin/bash: google-drive-ocamlfuse: command not found

# %% [markdown]
# -

# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')
path = '/content/drive/MyDrive/DA_WA-17/Data_Source/Data SIPSN TPS3R.csv'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dfbaru = pd.read_csv(path)

# %%
dfbaru
# Out:
#       Tahun      Provinsi  Sampahmasuk (ton/thn)  Sampahterkelola (ton/thn)
# 0      2021          Aceh                      0                          0
# 1      2021          Aceh                    183                        183
# 2      2021          Aceh                     34                         34
# 3      2021          Aceh                      4                          4
# 4      2021          Aceh                     13                         12
# ...     ...           ...                    ...                        ...
# 3968   2019  Maluku Utara                    219                        204
# 3969   2019  Maluku Utara                    183                        173
# 3970   2019  Maluku Utara                     12                         12
# 3971   2019         Papua                     73                         73
# 3972   2019         Papua                    110                        110
#
# [3973 rows x 4 columns]

# %%
dfbaru1=dfbaru.dropna()
dfbaru1=dfbaru.dropna(axis=0)

# %%
dfbaru1
# Out:
#       Tahun      Provinsi  Sampahmasuk (ton/thn)  Sampahterkelola (ton/thn)
# 0      2021          Aceh                      0                          0
# 1      2021          Aceh                    183                        183
# 2      2021          Aceh                     34                         34
# 3      2021          Aceh                      4                          4
# 4      2021          Aceh                     13                         12
# ...     ...           ...                    ...                        ...
# 3968   2019  Maluku Utara                    219                        204
# 3969   2019  Maluku Utara                    183                        173
# 3970   2019  Maluku Utara                     12                         12
# 3971   2019         Papua                     73                         73
# 3972   2019         Papua                    110                        110
#
# [3973 rows x 4 columns]

# %%
dfnew = dfbaru1.groupby(['Tahun', 'Provinsi']).sum()

# %%
dfnew
# Out:
#                          Sampahmasuk (ton/thn)  Sampahterkelola (ton/thn)
# Tahun Provinsi
# 2019  Aceh                                 595                        303
#       Bali                               21897                      16347
#       Banten                             21844                      11153
#       Bengkulu                             183                        119
#       D.I. Yogyakarta                    26527                       3687
# ...                                        ...                        ...
# 2021  Sulawesi Tenggara                   2756                         60
#       Sulawesi Utara                        96                         73
#       Sumatera Barat                      4879                       4846
#       Sumatera Selatan                    3258                       2867
#       Sumatera Utara                     13370                       1635
#
# [97 rows x 2 columns]

# %%
from google.colab import files

dfnew.to_csv('Data SIPSN TPS3R.csv', encoding = 'utf-8-sig') 
files.download('Data SIPSN TPS3R.csv')
